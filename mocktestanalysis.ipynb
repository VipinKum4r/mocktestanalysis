# %% [markdown]
# **MADE USING GOOGLE COLAB**

# %% [markdown]
# uploading file to google colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dab11955-710d-433f-a08c-974a0582e2a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dab11955-710d-433f-a08c-974a0582e2a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cgcmocktest.xlsx to cgcmocktest (2).xlsx

# %% [markdown]
# importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# readding the xlsx file

# %%
df=pd.read_excel("cgcmocktest.xlsx")

# %% [markdown]
# displaying the xlsx file

# %%
df
# Out:
#                     Email Address  Score             Name  \
# 0    mohansingh14052005@gmail.com      7     Mohan Singh
# 1     vishalthakur.kang@gmail.com     14   Vishal thakur
# 2            rachna6655@gmail.com     11     Rachna Singh
# 3         sumitkr.kr580@gmail.com     10      sumit kumar
# 4             ak2476597@gmail.com     13      Anil kumar
# ..                            ...    ...              ...
# 704    diksha8307836710@gmail.com     32           Diksha
# 705   surajbhatotia2001@gmail.com     31  Suraj Bhatotia
# 706       mushuverma292@gmail.com     11    Manisha Verma
# 707       chawlamanan76@gmail.com     29     Manan Chawla
# 708            nav30616@gmail.com     28     Navneet Kaur
#
#     University Roll No:-  Branch:- Semester:-
# 0                 2133319      MBA        2nd
# 1                 2020508      BCA        4th
# 2                 2020439      BCA        4th
# 3                 2027232      CSE        4th
# ...

# %% [markdown]
# displaying the columns

# %%
df.columns
# Out:
# Index(['Email Address', 'Score', 'Name', 'University Roll No:- ', 'Branch:-',
#        'Semester:-'],
#       dtype='object')

# %% [markdown]
# displaying common statistical values

# %%
df.describe()
# Out:
#             Score
# count  709.000000
# mean    30.126939
# std     10.669706
# min      5.000000
# 25%     22.000000
# 50%     32.000000
# 75%     39.000000
# max     47.000000

# %% [markdown]
# displaying number of columns

# %%
len(df.columns)
# Out:
# 6

# %% [markdown]
# displaying number of rows

# %%
len(df)
# Out:
# 709

# %% [markdown]
# displays the number of rows and columns

# %%
df.shape
# Out:
# (709, 6)

# %% [markdown]
# displaying common information of dataset

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Email Address  Score             Name  \
# 0    mohansingh14052005@gmail.com      7     Mohan Singh
# 1     vishalthakur.kang@gmail.com     14   Vishal thakur
# 2            rachna6655@gmail.com     11     Rachna Singh
# 3         sumitkr.kr580@gmail.com     10      sumit kumar
# 4             ak2476597@gmail.com     13      Anil kumar
# ..                            ...    ...              ...
# 704    diksha8307836710@gmail.com     32           Diksha
# 705   surajbhatotia2001@gmail.com     31  Suraj Bhatotia
# 706       mushuverma292@gmail.com     11    Manisha Verma
# 707       chawlamanan76@gmail.com     29     Manan Chawla
# 708            nav30616@gmail.com     28     Navneet Kaur
#
#     University Roll No:-  Branch:- Semester:-
# 0                 2133319      MBA        2nd
# 1                 2020508      BCA        4th
# 2                 2020439      BCA        4th
# 3                 2027232      CSE        4th
# ...

# %% [markdown]
# tells how many missing values do we have

# %%
missing_percentages=df.isna().sum().sort_values(ascending=False)/len(df) 
missing_percentages
# Out:
# Email Address            0.0
# Score                    0.0
# Name                     0.0
# University Roll No:-     0.0
# Branch:-                 0.0
# Semester:-               0.0
# dtype: float64

# %% [markdown]
# display the student with maximum score

# %%
df.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Email Address    yuvrajjashan@gmail.com
# Score                                47
# Name                      vishal thakur
# Branch:-                           aiml
# Semester:-                          6th
# dtype: object

# %% [markdown]
# display the student with minimum score

# %%
df.min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Email Address    04nancyforever@gmail.com
# Score                                   5
# Name                      Km Nidhi Sharma
# Branch:-                          AI & ML
# Semester:-                            2nd
# dtype: object

# %% [markdown]
# displaying the entire **Name** column

# %%
df["Name"]
# Out:
# 0         Mohan Singh
# 1       Vishal thakur
# 2         Rachna Singh
# 3          sumit kumar
# 4          Anil kumar
#             ...
# 704             Diksha
# 705    Suraj Bhatotia
# 706      Manisha Verma
# 707       Manan Chawla
# 708       Navneet Kaur
# Name: Name, Length: 709, dtype: object

# %% [markdown]
# display the name and university roll number of first 9 students

# %%
df[["Name","University Roll No:- "]][0:9]
# Out:
#              Name University Roll No:-
# 0    Mohan Singh                2133319
# 1  Vishal thakur                2020508
# 2    Rachna Singh               2020439
# 3     sumit kumar               2027232
# 4     Anil kumar                2020443
# 5     Deepak ojha               2020374
# 6          Diksha               2133275
# 7   Palak Sharma                1928848
# 8  Tawheed Rashid               2133404

# %% [markdown]
# displays the information of students from column 4 to 11

# %%
df.iloc[4:12]
# Out:
#                   Email Address  Score            Name University Roll No:-   \
# 4           ak2476597@gmail.com     13     Anil kumar                2020443
# 5      deepakojha7696@gmail.com     13     Deepak ojha               2020374
# 6         dikshaevil6@gmail.com     12          Diksha               2133275
# 7   palaksharmaps2401@gmail.com     20   Palak Sharma                1928848
# 8    tawheedrashid799@gmail.com     12  Tawheed Rashid               2133404
# 9     sainisaksham577@gmail.com     11       Sannnkkk              111111111
# 10      thakursejal07@gmail.com     12          Sejal                1928876
# 11   viveksharma90122@gmail.com     10   Vivek sharma                2020509
#
#      Branch:- Semester:-
# 4         BCA        4th
# 5         BCA        4th
# 6         MBA        2nd
# 7   B.Sc Agri        6th
# 8         MBA        2nd
# 9   B.Sc Agri        4th
# 10  B.Sc Agri        6th
# 11        BCA        4th

# %% [markdown]
# display the information of student with name **Vipin Kumar**

# %%
df.loc[df["Name"]=="Vipin Kumar"]
# Out:
#             Email Address  Score         Name University Roll No:-  Branch:-  \
# 389  vk24012002@gmail.com     18  Vipin Kumar               2027307      CSE
#
#     Semester:-
# 389        4th

# %% [markdown]
# displays all the students in cse branch

# %%
df.loc[df["Branch:-"]=="CSE"]
# Out:
#                       Email Address  Score              Name  \
# 3           sumitkr.kr580@gmail.com     10       sumit kumar
# 16   bhardwajprajwal47304@gmail.com     13  Prajwal bhardwaj
# 34          godaraanuj.bi@gmail.com     44        Anuj Kumar
# 36       ak.parmar1442000@gmail.com     44      Akash Parmar
# 38          nikhilgakhar2@gmail.com     43            Nikhil
# ..                              ...    ...               ...
# 687             nt1020300@gmail.com     31      Nitin Thakur
# 692          sk9888131360@gmail.com     40     Sudhir Kumar
# 696        itsmyofficial8@gmail.com     43             Sagar
# 697       purusharthmohla@gmail.com     29      Jatsya Mohla
# 707         chawlamanan76@gmail.com     29      Manan Chawla
#
#     University Roll No:-  Branch:- Semester:-
# 3                 2027232      CSE        4th
# 16                1915096      CSE        6th
# 34                1915339      CSE        6th
# 36                1915330      CSE        6th
# ...

# %% [markdown]
# displays all the students in 4th sem

# %%
df.loc[df["Semester:-"]=="4th"]
# Out:
#                     Email Address  Score             Name  \
# 1     vishalthakur.kang@gmail.com     14   Vishal thakur
# 2            rachna6655@gmail.com     11     Rachna Singh
# 3         sumitkr.kr580@gmail.com     10      sumit kumar
# 4             ak2476597@gmail.com     13      Anil kumar
# 5        deepakojha7696@gmail.com     13      Deepak ojha
# ..                            ...    ...              ...
# 691          samina6283@gmail.com     30           samina
# 694  karmandeepkaurguru@gmail.com     44  Karmandeep kaur
# 699        siwachaman88@gmail.com     31             Aman
# 704    diksha8307836710@gmail.com     32           Diksha
# 706       mushuverma292@gmail.com     11    Manisha Verma
#
#     University Roll No:-  Branch:- Semester:-
# 1                 2020508      BCA        4th
# 2                 2020439      BCA        4th
# 3                 2027232      CSE        4th
# 4                 2020443      BCA        4th
# ...

# %% [markdown]
# displays the information of students who scored more than 40 marks

# %%
df.loc[df["Score"]>40]
# Out:
#                       Email Address  Score                 Name  \
# 34          godaraanuj.bi@gmail.com     44           Anuj Kumar
# 36       ak.parmar1442000@gmail.com     44         Akash Parmar
# 38          nikhilgakhar2@gmail.com     43               Nikhil
# 44   mohitkarwasrabishnoi@gmail.com     42       Mohit Bishnoi
# 53     shobhitagarwal2309@gmail.com     46      Shobhit Agarwal
# ..                              ...    ...                  ...
# 671              gavrav12@gmail.com     44  Saurashtra Matawale
# 676          amangarg6272@gmail.com     43          Aman Gupta
# 686           sandiparya7@gmail.com     43         Sandip kumar
# 694    karmandeepkaurguru@gmail.com     44      Karmandeep kaur
# 696        itsmyofficial8@gmail.com     43                Sagar
#
#     University Roll No:-  Branch:- Semester:-
# 34                1915339      CSE        6th
# 36                1915330      CSE        6th
# 38                1915089      CSE        6th
# ...

# %% [markdown]
# arranging the dataframe in ascending order with respect to Names

# %%
df_sorted=df.sort_values("Name" , ascending=True)

# %% [markdown]
# displaying sorted dataframe

# %%
df_sorted
# Out:
#                         Email Address  Score                Name  \
# 390         sharmanidhi1322@gmail.com     43     Km Nidhi Sharma
# 239              tanyak1920@gmail.com     22               Tanya
# 21           prajjwalshah04@gmail.com     14                   .
# 99              ashokrd3120@gmail.com     30         ASHOKKUMAR
# 575       aakarshitjaggi005@gmail.com     44     Aakarshit jaggi
# ..                                ...    ...                 ...
# 184           s.k7527963527@gmail.com     25         sumit kumar
# 30            tariqbaigh746@gmail.com     18   tariq ahmad beigh
# 593          vickystudent01@gmail.com     39  vicky kumar sharma
# 69   vishalchoudhary2027033@gmail.com     32    vishal choudhary
# 209              vt.7851968@gmail.com     24       vishal thakur
#
#     University Roll No:-  Branch:- Semester:-
# 390               1915078      CSE        6th
# 239               2020490      BCA        4th
# 21                      .      ECE        6th
# ...

# %% [markdown]
# exporting sorte dataframe to csv format

# %%
df_sorted.to_csv("df_sorted.csv")

# %% [markdown]
# downloading the sorted csv

# %%
from google.colab import files
files.download('df_sorted.csv')

# %% [markdown]
# creating a new column and naming it Difference from passing marks

# %%
df["Difference from passing marks[25] : "] = df["Score"] - 25

# %% [markdown]
# printing the dataframe now which should consist of a new column

# %%
df
# Out:
#                     Email Address  Score             Name  \
# 0    mohansingh14052005@gmail.com      7     Mohan Singh
# 1     vishalthakur.kang@gmail.com     14   Vishal thakur
# 2            rachna6655@gmail.com     11     Rachna Singh
# 3         sumitkr.kr580@gmail.com     10      sumit kumar
# 4             ak2476597@gmail.com     13      Anil kumar
# ..                            ...    ...              ...
# 704    diksha8307836710@gmail.com     32           Diksha
# 705   surajbhatotia2001@gmail.com     31  Suraj Bhatotia
# 706       mushuverma292@gmail.com     11    Manisha Verma
# 707       chawlamanan76@gmail.com     29     Manan Chawla
# 708            nav30616@gmail.com     28     Navneet Kaur
#
#     University Roll No:-  Branch:- Semester:-  \
# 0                 2133319      MBA        2nd
# 1                 2020508      BCA        4th
# 2                 2020439      BCA        4th
# 3                 2027232      CSE        4th
# ...

# %% [markdown]
# deleting the new column which we just made above

# %%
df=df.drop(columns=["Difference from passing marks[25] : "])

# %% [markdown]
# displaying the dataframe , the new column should now be deleted

# %%
df
# Out:
#                     Email Address  Score             Name  \
# 0    mohansingh14052005@gmail.com      7     Mohan Singh
# 1     vishalthakur.kang@gmail.com     14   Vishal thakur
# 2            rachna6655@gmail.com     11     Rachna Singh
# 3         sumitkr.kr580@gmail.com     10      sumit kumar
# 4             ak2476597@gmail.com     13      Anil kumar
# ..                            ...    ...              ...
# 704    diksha8307836710@gmail.com     32           Diksha
# 705   surajbhatotia2001@gmail.com     31  Suraj Bhatotia
# 706       mushuverma292@gmail.com     11    Manisha Verma
# 707       chawlamanan76@gmail.com     29     Manan Chawla
# 708            nav30616@gmail.com     28     Navneet Kaur
#
#     University Roll No:-  Branch:- Semester:-
# 0                 2133319      MBA        2nd
# 1                 2020508      BCA        4th
# 2                 2020439      BCA        4th
# 3                 2027232      CSE        4th
# ...

# %% [markdown]
# filtering out the results of some selected students

# %%
vipin=df.loc[df["Name"]=="Vipin Kumar"]
nitin=df.loc[df["Email Address"]=="nitinhanda001@gmail.com"]
dheeraj=df.loc[df["Email Address"]=="dheerajyadav2603@gmail.com"]
ankit=df.loc[df["Email Address"]=="ankit.as.singh12@gmail.com"]
amanyadav=df.loc[df["Email Address"]=="cools7860@gmail.com"]
nishtha=df.loc[df["Name"]=="Nishtha Jain"]

# %% [markdown]
# displaying the information of student **Vipin**

# %%
vipin
# Out:
#             Email Address  Score         Name University Roll No:-  Branch:-  \
# 389  vk24012002@gmail.com     18  Vipin Kumar               2027307      CSE
#
#     Semester:-
# 389        4th

# %% [markdown]
# displaying the information of student **Ntitn**

# %%
nitin
# Out:
#                Email Address  Score    Name University Roll No:-    Branch:-  \
# 395  nitinhanda001@gmail.com     18  Nitin                2027283  Ai and ml
#
#     Semester:-
# 395        4th

# %% [markdown]
# displaying the information of student **Nishtha**

# %%
nishtha
# Out:
#                     Email Address  Score          Name University Roll No:-   \
# 553  bloomingflowers737@gmail.com     25  Nishtha Jain               2027282
#
#     Branch:- Semester:-
# 553     AIML        4th

# %% [markdown]
# displaying the information of student **Dheeraj**

# %%
dheeraj
# Out:
#                   Email Address  Score           Name University Roll No:-   \
# 109  dheerajyadav2603@gmail.com     46  Dheeraj Yadav               2027266
#
#     Branch:- Semester:-
# 109  Ai & ML        4th

# %% [markdown]
# displaying the information of student **Ankit**

# %%
ankit
# Out:
#                  Email Address  Score         Name University Roll No:-   \
# 81  ankit.as.singh12@gmail.com     43  Ankit singh               2027253
#
#    Branch:- Semester:-
# 81      CSE        4th

# %% [markdown]
# combining the results of the above students into a single dataframe

# %%
phirands = pd.concat([vipin, nitin,dheeraj,ankit,amanyadav,nishtha])

# %% [markdown]
# displaying the dataframe **phirands**

# %%
phirands
# Out:
#                     Email Address  Score           Name University Roll No:-   \
# 389          vk24012002@gmail.com     18    Vipin Kumar               2027307
# 395       nitinhanda001@gmail.com     18         Nitin                2027283
# 109    dheerajyadav2603@gmail.com     46  Dheeraj Yadav               2027266
# 81     ankit.as.singh12@gmail.com     43    Ankit singh               2027253
# 362           cools7860@gmail.com     41    Aman Yadav                2027251
# 553  bloomingflowers737@gmail.com     25   Nishtha Jain               2027282
#
#       Branch:- Semester:-
# 389        CSE        4th
# 395  Ai and ml        4th
# 109    Ai & ML        4th
# 81         CSE        4th
# 362        CSE        4th
# 553       AIML        4th

# %% [markdown]
# plotting the score chart for comparision of scores of phirands dataframe

# %%
plt.bar("Name","Score",data=phirands,color="Blue",width=0.7)
plt.xlabel("Names")
plt.ylabel("Scores")
plt.title("Phirands score comparision")
plt.xticks(rotation=90)
plt.figure(figsize=(200,200))
plt.show()
